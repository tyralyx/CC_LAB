# %% [markdown]
# <a href="https://colab.research.google.com/github/AnirudhPhophalia/AnirudhPhophalia_UCS420_CC_Assignments/blob/main/cc_ac1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Assingment 1.1: WAP to print your name three times

# %%
for _ in range(3):
    print("Anirudh Phophalia")
# Out:
# Anirudh Phophalia
# Anirudh Phophalia
# Anirudh Phophalia

# %% [markdown]
# ### Assingment 2.1: WAP to add three numbers and print the result.

# %%
n1 = int(input("first\n"))
n2 = int(input("second\n"))
n3 = int(input("third\n"))
sum = n1 + n2 + n3
print("sum=", sum)
# Out:
# first
# 25
# second
# 35
# third
# 52
# sum=  112

# %% [markdown]
# Assingment 2.2: WAP to concatinate three strings and print the result.

# %%
s1 = "Anirudh"
s2 = " "
s3 = "Phophalia"

cs = s1 + s2 + s3

print("cs:", cs)
# Out:
# cs: Anirudh Phophalia

# %% [markdown]
# ### Assignment 4.1: WAP to print the table of 7, 9.

# %%
print("7 Table")
for i in range(1, 11):
    print(f"7 x {i} = {7 * i}")

print("\n9 Table")
for i in range(1, 11):
    print(f"9 x {i} = {9 * i}")
# Out:
# 7 Table
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
#
# 9 Table
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# ### Assignment 4.2: WAP to print the table of n and n is given by user.

# %%
n = int(input("enter\n"))

print(f"\n{n} Table")
for i in range(1, 11):
    print(f"{n} x {i} = {n * i}")
# Out:
# enter
# 5
#
# Table of 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# ### Assignment 4.3: WAP to add all the numbers from 1 to n and n is given by user.

# %%
n = int(input("enter\n"))
sum = 0

for i in range(1, n + 1):
    sum += i

print(f"sum: {sum}")
# Out:
# enter
# 5
# sum: 15

# %% [markdown]
# ### Assignment 5.1: WAP to find max among three numbers and input from user. [Try max() function]

# %%
n1 = int(input("first\n"))
n2 = int(input("second\n"))
n3 = int(input("third\n"))

maxi = max(n1, n2, n3)

print(f"maximum: {maxi}")
# Out:
# first
# 56
# second
# 25
# third
# 465
# maximum: 465

# %% [markdown]
# ### Assignment 5.2: WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user.

# %%
n = int(input("enter\n"))
sum = 0

for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        sum += i

print(f"sum : {sum}")
# Out:
# enter
# 150
# sum : 189

# %% [markdown]
# ### Assignment 5.3: WAP to add all prime numbers from 1 to n and n is given by the user.

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

n = int(input("enter\n"))
sum = 0

for i in range(1, n + 1):
    if is_prime(i):
        sum += i

print(f"sum: {sum}")
# Out:
# enter
# 5
# sum: 10

# %% [markdown]
# ### Assignment 6.1: WAP using function that add all odd numbers from 1 to n, n is given by the user.

# %%
def sum_odd(n):
    sum = 0
    for i in range(1, n + 1):
        if i % 2 != 0:
            sum += i
    return sum

n = int(input("enter\n"))
res = sum_odd(n)
print(f"sum: {res}")
# Out:
# enter
# 5
# sum: 9

# %% [markdown]
# ### Assignment 6.2: WAP using function that add all prime numbers from 1 to n, n given by the user.

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

def sum_prime(n):
    total = 0
    for i in range(1, n + 1):
        if is_prime(i):
            total += i
    return total

n_sum = int(input("enter\n"))
res = sum_prime(n_sum)
print(f"sum: {res}")
# Out:
# enter
# 52
# sum: 328
